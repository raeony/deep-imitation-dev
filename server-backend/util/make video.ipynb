# %%
import cv2
import os

listd = os.listdir('/media/yaosy/办公/bdmeet/yaosy/merge_result/')
data_dir = '/media/yaosy/办公/bdmeet/yaosy/merge_result/'

# %%
listd[0].split('_')[1][:4]
# Out:
# '0000'

# %%
fps = 20
size = (512, 512)
videowriter= cv2.VideoWriter('yaosy_merge_20fps.avi', cv2.VideoWriter_fourcc(*'XVID'), fps, size)
for i in range(3315):
    num = listd[i].split('_')[1][:4]
    name = 'merge_{}.png'.format(num)
    print(name)
    print(os.path.join(data_dir, name))
    img = cv2.imread(os.path.join(data_dir, name))
    print(img.shape)
    videowriter.write(img)
# Out:
# merge_0000.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0000.png
# (512, 512, 3)
# merge_0001.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0001.png
# (512, 512, 3)
# merge_0002.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0002.png
# (512, 512, 3)
# merge_0003.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0003.png
# (512, 512, 3)
# merge_0004.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0004.png
# (512, 512, 3)
# merge_0005.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0005.png
# (512, 512, 3)
# merge_0006.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0006.png
# (512, 512, 3)
# merge_0007.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0007.png
# (512, 512, 3)
# merge_0008.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0008.png
# (512, 512, 3)
# merge_0009.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0009.png
# (512, 512, 3)
# merge_0010.png
# /media/yaosy/办公/bdmeet/yaosy/merge_result/merge_0010.png
# ...
